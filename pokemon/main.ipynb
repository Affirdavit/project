# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')
df = data.copy()

# %%
data.head()
# Out:
#    Number        Name           Form Type 1  Type 2  HP  Attack  Defense  \
# 0       1   Bulbasaur            NaN  Grass  Poison  45      49       49
# 1       2     Ivysaur            NaN  Grass  Poison  60      62       63
# 2       3    Venusaur            NaN  Grass  Poison  80      82       83
# 3       3    Venusaur  Mega Venusaur  Grass  Poison  80     100      123
# 4       4  Charmander            NaN   Fire     NaN  39      52       43
#
#    Sp.Attack  Sp.Defense  Speed
# 0         65          65     45
# 1         80          80     60
# 2        100         100     80
# 3        122         120     80
# 4         60          50     65

# %%
df.shape
# Out:
# (1215, 11)

# %%
df.describe(exclude='number')
# Out:
#          Name             Form Type 1  Type 2
# count    1215              230   1215     669
# unique   1025              208     18      18
# top     Rotom  Incarnate Forme  Water  Flying
# freq        6                4    150     122

# %%
sns.pairplot(data=df[['HP', 'Attack', 'Defense', 'Sp.Attack', 'Sp.Defense', 'Speed']])
plt.show()

# %%
df.value_counts('Type 1').reset_index()
# Out:
#       Type 1  count
# 0      Water    150
# 1     Normal    134
# 2      Grass    113
# 3        Bug     91
# 4    Psychic     82
# 5       Fire     76
# 6   Electric     74
# 7       Rock     68
# 8       Dark     56
# 9   Fighting     50
# 10    Dragon     49
# 11    Poison     49
# 12     Ghost     47
# 13    Ground     47
# 14     Steel     45
# 15       Ice     43
# 16     Fairy     31
# 17    Flying     10
