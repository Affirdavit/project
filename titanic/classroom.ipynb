# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
test = pd.read_csv('./data/test.csv')
train = pd.read_csv('./data/train.csv')

# %%
test.sample(10)
# Out:
#      PassengerId  Pclass                                               Name  \
# 360         1252       3                        Sage, Master. William Henry
# 241         1133       2                      Christy, Mrs. (Alice Frances)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 152         1044       3                                 Storey, Mr. Thomas
# 206         1098       3                           McGowan, Miss. Katherine
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 150         1042       1              Earnshaw, Mrs. Boulton (Olive Potter)
# 213         1105       2       Howard, Mrs. Benjamin (Ellen Truelove Arman)
# 97           989       3                          Makinen, Mr. Kalle Edvard
# 410         1302       3                             Naughton, Miss. Hannah
#
#         Sex   Age  SibSp  Parch             Ticket      Fare        Cabin  \
# ...

# %%
titanic = pd.DataFrame({'sex': ['male', 'female'], 'value': [300, 400]})

# %%
titanic.plot.barh(x='sex', y='value')
# Out:
# <Axes: ylabel='sex'>
